# %% [markdown]
# ### Test Reinforcement Learning for Supply Chain Optimization
# 1. Run the tests

# %%
# %run testing.py
# Out:
# ========= Step:   0 =========
# State:          [25  5  2  2]
# Action:         [0 0]
# Reward:         3.7
# Next state:     [25  3  2  2]
# Episode reward: 3.7
# ========= Step:   1 =========
# State:          [25  3  2  2]
# Action:         [3 3]
# Reward:         -2.5
# Next state:     [25  5  1  2]
# Episode reward: 1.2
# ========= Step:   2 =========
# State:          [25  5  1  2]
# Action:         [0 0]
# Reward:         1.6
# Next state:     [25  4  1  1]
# Episode reward: 2.8
# ========= Step:   3 =========
# State:          [25  4  1  1]
# Action:         [3 3]
# Reward:         -2.6
# Next state:     [25  6  1  1]
# Episode reward: 0.2
# ========= Step:   4 =========
# State:          [25  6  1  1]
# Action:         [0 0]
# Reward:         1.5
# Next state:     [25  5  1  1]
# Episode reward: 1.7
# ========= Step:   5 =========
# State:          [25  5  1  1]
# Action:         [0 0]
# Reward:         1.6
# Next state:     [25  4  1  1]
# Episode reward: 3.3
# ...

# %% [markdown]
# 2. Plot the results

# %%
# %run graph_creation.py
